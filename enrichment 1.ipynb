# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/M Yusuf/hacktiv8/DATA/archive/trending.csv")

# %%
num_rows, num_cols = df.shape
print("num_rows:", num_rows)
print("num_cols:", num_cols)
# Out:
# num_rows: 14523
# num_cols: 26

# %%
df.head(10)
# Out:
#            publish_time                channel_id  \
# 0  2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1  2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2  2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3  2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4  2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
# 5  2021-02-03T12:00:03Z  UC6FjcBcH9NVHdfFSvNfHmuA
# 6  2021-02-02T13:39:46Z  UCRVhCi6T_-Ogs9MPDh3kX1w
# 7  2021-02-06T03:46:12Z  UCfx3oPv3cJm2aCJ7UnhKx8A
# 8  2021-02-03T13:03:47Z  UCmlgRPrwvyHaS1jYXJifNqg
# 9  2021-01-28T07:00:07Z  UCdpxBSzxXGz_J4K30YGvk_Q
#
#                                                title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
# 5  SEMPROD: RAFFI AHMAD NONGKRONG SAMA GADING UUS...
# ...

# %%
df.tail(15)
# Out:
#                publish_time                channel_id  \
# 14508  2021-05-24T06:23:46Z  UCwFc1bMj5KFxX8BJ1wBRuzw
# 14509  2021-05-12T12:00:35Z  UCI4XW5E1aeXlRo9tZ2s0AZg
# 14510  2021-05-26T06:04:18Z  UCmCKu42dBpkfVpxSzp7d9Kg
# 14511  2021-05-25T12:25:47Z  UCFuM3BWlLM3YbLjkXBiJ8-A
# 14512  2021-05-22T03:16:41Z  UCfzg8Jo-o3tlkenRhLPjSoA
# 14513  2021-05-22T10:00:33Z  UCdH-Rw8RBSBHwYWZtfCu1Qw
# 14514  2021-05-19T13:22:31Z  UChO8h2G8UjOVc081rgYU8XQ
# 14515  2021-05-08T10:12:03Z  UCRhmWtGmW2lJ_CNGXP6hvIQ
# 14516  2021-05-21T13:00:17Z  UCQrLfLd8y0ncipsXkb_w_SQ
# 14517  2021-05-18T14:00:15Z  UCyLHKUjX_fy8akafmRMr-PA
# 14518  2021-05-18T14:59:58Z  UCzgxx_DM2Dcb9Y1spb9mUJA
# 14519  2021-05-24T09:48:50Z  UC8nOUvbfUqYRufAAFBFz72g
# 14520  2021-05-13T07:00:06Z  UCdpxBSzxXGz_J4K30YGvk_Q
# 14521  2021-05-21T10:29:06Z  UCwIzd032IQjvJ9larkdcwgg
# 14522  2021-05-22T06:00:09Z  UCfine-VxsozjW6FnssQkwLg
#
#                                                    title  \
# ...

# %%
with pd.option_context("display.max.columns", None) :
    display(df.head())
# Out:
#            publish_time                channel_id  \
# 0  2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1  2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2  2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3  2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4  2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
#
#                                                title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
#
#                                          description  thumbnail_url  \
# 0  aespa's new single "Forever" is out!\nListen a...            NaN
# 1  Jakarta, https://www.tvonenews.com - Ketua umu...            NaN
# 2  Road Party Season 2: Cabriolet Challenge\n\nEp...            NaN
# ...

# %%
with pd.option_context("display.max.columns", None, "display.precision", 2) :
    display(df.head())
# Out:
#            publish_time                channel_id  \
# 0  2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1  2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2  2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3  2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4  2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
#
#                                                title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
#
#                                          description  thumbnail_url  \
# 0  aespa's new single "Forever" is out!\nListen a...            NaN
# 1  Jakarta, https://www.tvonenews.com - Ketua umu...            NaN
# 2  Road Party Season 2: Cabriolet Challenge\n\nEp...            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14523 entries, 0 to 14522
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   publish_time       14523 non-null  object
#  1   channel_id         14523 non-null  object
#  2   title              14523 non-null  object
#  3   description        14246 non-null  object
#  4   thumbnail_url      0 non-null      float64
#  5   thumbnail_width    0 non-null      float64
#  6   thumbnail_height   0 non-null      float64
#  7   channel_name       14523 non-null  object
#  8   tags               12983 non-null  object
#  9   category_id        14523 non-null  int64
#  10  live_status        14523 non-null  object
#  11  local_title        14523 non-null  object
#  12  local_description  14246 non-null  object
#  13  duration           14523 non-null  object
#  14  dimension          14523 non-null  object
#  15  definition         14523 non-null  object
# ...

# %%
df.describe()
# Out:
#        thumbnail_url  thumbnail_width  thumbnail_height   category_id  \
# count            0.0              0.0               0.0  14523.000000
# mean             NaN              NaN               NaN     18.668250
# std              NaN              NaN               NaN      7.332783
# min              NaN              NaN               NaN      1.000000
# 25%              NaN              NaN               NaN     10.000000
# 50%              NaN              NaN               NaN     23.000000
# 75%              NaN              NaN               NaN     24.000000
# max              NaN              NaN               NaN     29.000000
#
#                view          like        dislike  favorite       comment
# count  1.451500e+04  1.431200e+04   14312.000000   14523.0  1.440700e+04
# mean   2.831619e+06  1.401115e+05    3272.803382       0.0  1.947793e+04
# std    8.589446e+06  5.385763e+05   12569.324616       0.0  1.533488e+05
# ...

# %%
df.describe(include="object")
# Out:
#                 publish_time                channel_id  \
# count                  14523                     14523
# unique                  3386                      1092
# top     2021-04-01T09:00:15Z  UCYk4LJI0Pr6RBDWowMm-KUw
# freq                      25                       147
#
#                                                     title  \
# count                                               14523
# unique                                               3458
# top     Top Lagu Pop Indonesia Terbaru 2021 Hits Pilih...
# freq                                                   35
#
#                                               description     channel_name  \
# count                                               14246            14523
# unique                                               3313             1093
# top     Talk show malam yang akan memberikan informasi...  Deddy Corbuzier
# freq                                                   62              147
#
# ...

# %%
df.describe(include="number")
# Out:
#        thumbnail_url  thumbnail_width  thumbnail_height   category_id  \
# count            0.0              0.0               0.0  14523.000000
# mean             NaN              NaN               NaN     18.668250
# std              NaN              NaN               NaN      7.332783
# min              NaN              NaN               NaN      1.000000
# 25%              NaN              NaN               NaN     10.000000
# 50%              NaN              NaN               NaN     23.000000
# 75%              NaN              NaN               NaN     24.000000
# max              NaN              NaN               NaN     29.000000
#
#                view          like        dislike  favorite       comment
# count  1.451500e+04  1.431200e+04   14312.000000   14523.0  1.440700e+04
# mean   2.831619e+06  1.401115e+05    3272.803382       0.0  1.947793e+04
# std    8.589446e+06  5.385763e+05   12569.324616       0.0  1.533488e+05
# ...

# %%
df.describe(include="all").T
# Out:
#                    count unique  \
# publish_time       14523   3386
# channel_id         14523   1092
# title              14523   3458
# description        14246   3313
# thumbnail_url          0    NaN
# thumbnail_width        0    NaN
# thumbnail_height       0    NaN
# channel_name       14523   1093
# tags               12983   2474
# category_id        14523    NaN
# live_status        14523      1
# local_title        14523   3458
# local_description  14246   3313
# duration           14523   1507
# dimension          14523      1
# definition         14523      2
# caption            14523      2
# license_status     14523      2
# allowed_region       493     30
# blocked_region       714     81
# view               14515    NaN
# like               14312    NaN
# dislike            14312    NaN
# favorite           14523    NaN
# comment            14407    NaN
# trending_time      14523  14523
#
# ...

# %%
df.columns
# Out:
# Index(['publish_time', 'channel_id', 'title', 'description', 'thumbnail_url',
#        'thumbnail_width', 'thumbnail_height', 'channel_name', 'tags',
#        'category_id', 'live_status', 'local_title', 'local_description',
#        'duration', 'dimension', 'definition', 'caption', 'license_status',
#        'allowed_region', 'blocked_region', 'view', 'like', 'dislike',
#        'favorite', 'comment', 'trending_time'],
#       dtype='object')

# %%
print(type(df.columns))
print(df.columns)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['publish_time', 'channel_id', 'title', 'description', 'thumbnail_url',
#        'thumbnail_width', 'thumbnail_height', 'channel_name', 'tags',
#        'category_id', 'live_status', 'local_title', 'local_description',
#        'duration', 'dimension', 'definition', 'caption', 'license_status',
#        'allowed_region', 'blocked_region', 'view', 'like', 'dislike',
#        'favorite', 'comment', 'trending_time'],
#       dtype='object')

# %%
df.head()
# Out:
#            publish_time                channel_id  \
# 0  2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1  2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2  2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3  2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4  2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
#
#                                                title  \
# 0                        aespa 에스파 'Forever (약속)' MV
# 1  [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2     CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                        With Windah Basudara & Hans
# 4  🤯 LATE COMEBACK DRAMA! | HIGHLIGHTS | Granada ...
#
#                                          description  thumbnail_url  \
# 0  aespa's new single "Forever" is out!\nListen a...            NaN
# 1  Jakarta, https://www.tvonenews.com - Ketua umu...            NaN
# 2  Road Party Season 2: Cabriolet Challenge\n\nEp...            NaN
# ...

# %%
df["channel_id"].value_counts()
# Out:
# UCYk4LJI0Pr6RBDWowMm-KUw    147
# UC24_Z2L-8Ki183AI9zJJzNQ    145
# UCpr5mSSUbIQU816dNjaDdyg    128
# UC5BMIWZe9isJXLZZWPWvBlg    123
# UCEf_Bc-KVd7onSeifS3py9g    123
#                            ...
# UCCt4LNqlwlgsWA28WvNxcCw      1
# UCkmF9-L907T0I0jhQnERhnw      1
# UCtD2hfWNpkh4fynfmx9xJCQ      1
# UCb0otfoyPjSxF2bLbahjxlA      1
# UCzsF1ghKHeif7AmTNlRYAzQ      1
# Name: channel_id, Length: 1092, dtype: int64

# %%
df["channel_id"].value_counts().head(20)
# Out:
# UCYk4LJI0Pr6RBDWowMm-KUw    147
# UC24_Z2L-8Ki183AI9zJJzNQ    145
# UCpr5mSSUbIQU816dNjaDdyg    128
# UC5BMIWZe9isJXLZZWPWvBlg    123
# UCEf_Bc-KVd7onSeifS3py9g    123
# UCEHprhvK2xu0CYKcnbMshBw    116
# UCwIzd032IQjvJ9larkdcwgg    106
# UCYqOeAXJm8yV9sJ8Ud3cR7A    103
# UCGXnDxirLuSrIHwQXWxRzeg    103
# UCLojthXNTLMGp6XSp4wgPRw    102
# UCC6SejZDisqDrBmc37dVE1A     93
# UCBJeMCIeLQos7wacox4hmLQ     92
# UCyNjDKW9XGAsUdmv21KDwFA     90
# UCER4rvDnRBPr_ncYW4UCZjg     90
# UCmxAIW7RDDC88EPk4ry16Kg     89
# UChFRHojUZJ9KfC4SHcN5wZA     88
# UCmB1_agPlXbbwTCPKEuwEKA     86
# UCaxNFw2ryxzjSAxRVP-0Dfg     84
# UCaKLg1ELiX0zTJ6Je3c5esA     75
# UC43nz9qnZ7AIrbOlfxejTig     74
# Name: channel_id, dtype: int64

# %%
df["channel_id"].value_counts().tail(20)
# Out:
# UCKNZsAeQXpvI-Mpoc0ZKhsA    1
# UCD_fhk1uFl_JpJVhZtgL4bw    1
# UCNMCozStlkA0wAXMHPuAgDA    1
# UCsfBhdQQmE0NuljXe-Gl5Dg    1
# UC1t0D_DTMpICiEfO4FZxnGw    1
# UCnTB-B8A9SKJiXZFX-VqSfw    1
# UC99IVRmbb0vJZ1Vge2HtMHg    1
# UC134LS-hsuP28mcMCsRdUhQ    1
# UCgrNz-aDmcr2uuto8_DL2jg    1
# UCKl0lSAwg7B50fuvyi9li3Q    1
# UCkUm5N7OmgXmVqpJoNMIsYg    1
# UC42ZduLx6o3Nqg04kMuMCEw    1
# UCycj6O-hdZtR0vJxXB8jrLw    1
# UCyGa1YEx9ST66rYrJTGIKOw    1
# UCSWwb_YyNB8vuC1VDcfPPaQ    1
# UCCt4LNqlwlgsWA28WvNxcCw    1
# UCkmF9-L907T0I0jhQnERhnw    1
# UCtD2hfWNpkh4fynfmx9xJCQ    1
# UCb0otfoyPjSxF2bLbahjxlA    1
# UCzsF1ghKHeif7AmTNlRYAzQ    1
# Name: channel_id, dtype: int64

# %%
df["channel_id"].nunique()
# Out:
# 1092

# %%
df["channel_id"].unique()
# Out:
# array(['UCEf_Bc-KVd7onSeifS3py9g', 'UCYEa4_MC7OFjcWrO6SO-u8g',
#        'UCu12RxQjRQyh79YBYvEDkOg', ..., 'UCJHC3VbFsp7kJ2NxPGltwiw',
#        'UCFQoE23adk7NSPNhBlanu4w', 'UC8nOUvbfUqYRufAAFBFz72g'],
#       dtype=object)

# %%
df["view"].value_counts()
# Out:
# 174888.0      2
# 1292241.0     2
# 130356.0      2
# 1136591.0     2
# 2699055.0     2
#              ..
# 3889133.0     1
# 2578411.0     1
# 59697455.0    1
# 939510.0      1
# 22528.0       1
# Name: view, Length: 14454, dtype: int64

# %%
df["view"].nunique()
# Out:
# 14454

# %%
df["view"].unique()
# Out:
# array([7806846.,  885038.,  889708., ..., 2424980., 2014523.,  225558.])

# %%
df["category_id"].value_counts()
# Out:
# 24    4409
# 10    3653
# 25    1572
# 22    1307
# 17    1132
# 1      519
# 26     502
# 23     413
# 2      248
# 20     246
# 27     141
# 29     123
# 28     117
# 15      85
# 19      56
# Name: category_id, dtype: int64

# %%
df["category_id"].nunique()
# Out:
# 15

# %%
df["category_id"].unique()
# Out:
# array([10, 25,  2, 20, 17, 24, 23, 22, 26, 29,  1, 27, 28, 15, 19],
#       dtype=int64)

# %%
df["category_id"].value_counts().index
# Out:
# Int64Index([24, 10, 25, 22, 17, 1, 26, 23, 2, 20, 27, 29, 28, 15, 19], dtype='int64')

# %%
df.columns
# Out:
# Index(['publish_time', 'channel_id', 'title', 'description', 'thumbnail_url',
#        'thumbnail_width', 'thumbnail_height', 'channel_name', 'tags',
#        'category_id', 'live_status', 'local_title', 'local_description',
#        'duration', 'dimension', 'definition', 'caption', 'license_status',
#        'allowed_region', 'blocked_region', 'view', 'like', 'dislike',
#        'favorite', 'comment', 'trending_time'],
#       dtype='object')

# %%
summary_cols = ["publish_time", "channel_id", "channel_name", "category_id", "view", "like", "dislike", "trending_time"]
df_summary = df[summary_cols].copy()
df_summary
# Out:
#                publish_time                channel_id  \
# 0      2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1      2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2      2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3      2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4      2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
# ...                     ...                       ...
# 14518  2021-05-18T14:59:58Z  UCzgxx_DM2Dcb9Y1spb9mUJA
# 14519  2021-05-24T09:48:50Z  UC8nOUvbfUqYRufAAFBFz72g
# 14520  2021-05-13T07:00:06Z  UCdpxBSzxXGz_J4K30YGvk_Q
# 14521  2021-05-21T10:29:06Z  UCwIzd032IQjvJ9larkdcwgg
# 14522  2021-05-22T06:00:09Z  UCfine-VxsozjW6FnssQkwLg
#
#                   channel_name  category_id       view      like  dislike  \
# 0                       SMTOWN           10  7806846.0  857902.0  24078.0
# 1       Indonesia Lawyers Club           25   885038.0    6765.0   1263.0
# 2                     Motomobi            2   889708.0   47895.0    532.0
# ...

# %%
df_summary.loc[:5, ["like", "dislike"]]
# Out:
#        like  dislike
# 0  857902.0  24078.0
# 1    6765.0   1263.0
# 2   47895.0    532.0
# 3   91973.0   3967.0
# 4  218131.0   4289.0
# 5   63530.0    978.0

# %%
df_summary.loc[[0, 2, 4, 6, 8], ["channel_name", "view"]]
# Out:
#                 channel_name       view
# 0                     SMTOWN  7806846.0
# 2                   Motomobi   889708.0
# 4               FC Barcelona  6275035.0
# 6  Apa Kabar Indonesia tvOne  1493171.0
# 8                Picky Picks  1955271.0

# %%
df_summary.iloc[:10, [-2, -1]]
# Out:
#    dislike                     trending_time
# 0  24078.0  2021-02-07 05:46:51.832614+00:00
# 1   1263.0  2021-02-07 05:46:51.832649+00:00
# 2    532.0  2021-02-07 05:46:51.832664+00:00
# 3   3967.0  2021-02-07 05:46:51.832678+00:00
# 4   4289.0  2021-02-07 05:46:51.832730+00:00
# 5    978.0  2021-02-07 05:46:51.832751+00:00
# 6   1694.0  2021-02-07 05:46:51.832766+00:00
# 7   2339.0  2021-02-07 05:46:51.832780+00:00
# 8   1586.0  2021-02-07 05:46:51.832791+00:00
# 9  14383.0  2021-02-07 05:46:51.832803+00:00

# %%
df_summary.loc[0]
# Out:
# publish_time                 2021-02-05T09:00:34Z
# channel_id               UCEf_Bc-KVd7onSeifS3py9g
# channel_name                               SMTOWN
# category_id                                    10
# view                                  7.80685e+06
# like                                       857902
# dislike                                     24078
# trending_time    2021-02-07 05:46:51.832614+00:00
# Name: 0, dtype: object

# %%
df_summary[df_summary["channel_name"] == "SMTOWN"]
# Out:
#                publish_time                channel_id channel_name  \
# 0      2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 18     2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 200    2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 219    2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 402    2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# ...                     ...                       ...          ...
# 13966  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 14142  2021-05-17T09:00:02Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 14182  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 14345  2021-05-17T09:00:02Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 14391  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
#
#        category_id        view       like  dislike  \
# 0               10   7806846.0   857902.0  24078.0
# 18              10   1926293.0   274399.0   6301.0
# ...

# %%
df_SMTOWN_view = df_summary[
    (df_summary["channel_name"] == "SMTOWN")
    & (df_summary.like > df_summary.dislike)
]

# %%
df_SMTOWN_view["like"].value_counts()
# Out:
# 429567.0     1
# 871243.0     1
# 990797.0     1
# 1045326.0    1
# 1015631.0    1
#             ..
# 659377.0     1
# 274522.0     1
# 619957.0     1
# 659697.0     1
# 927749.0     1
# Name: like, Length: 123, dtype: int64

# %%
df_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14523 entries, 0 to 14522
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   publish_time   14523 non-null  object
#  1   channel_id     14523 non-null  object
#  2   channel_name   14523 non-null  object
#  3   category_id    14523 non-null  int64
#  4   view           14515 non-null  float64
#  5   like           14312 non-null  float64
#  6   dislike        14312 non-null  float64
#  7   trending_time  14523 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 907.8+ KB

# %%
df_summary.loc[
    (df_summary.view >= 2021)
    & (df_summary.like > df_summary.dislike),
    "channel_name"
].value_counts()
# Out:
# TRANS7 OFFICIAL         145
# Deddy Corbuzier         143
# Indonesian Idol         128
# SMTOWN                  123
# KOMPASTV                123
#                        ...
# boboucool TV              1
# CGTN                      1
# 5-Minute Crafts PLAY      1
# MBC Radio봉춘라디오            1
# Stephanie Poetri          1
# Name: channel_name, Length: 1078, dtype: int64

# %%
df.loc[
    (df["channel_name"] == "SMTOWN") & (df["channel_id"].str.startswith("UC")),
    ["view", "like", "dislike", "trending_time"]
]
# Out:
#              view       like  dislike                     trending_time
# 0       7806846.0   857902.0  24078.0  2021-02-07 05:46:51.832614+00:00
# 18      1926293.0   274399.0   6301.0  2021-02-07 05:46:51.833035+00:00
# 200     8535337.0   880061.0  26084.0  2021-02-07 12:15:58.377224+00:00
# 219     1936376.0   274844.0   6327.0  2021-02-07 12:15:58.377496+00:00
# 402     9745275.0   927749.0  29544.0  2021-02-08 11:56:45.332377+00:00
# ...           ...        ...      ...                               ...
# 13966  84903561.0  2605165.0  39265.0  2021-05-25 06:01:04.439292+00:00
# 14142  79332005.0  1788357.0  66371.0  2021-05-26 06:00:47.429526+00:00
# 14182  85962829.0  2626361.0  39584.0  2021-05-26 06:00:47.429853+00:00
# 14345  80349313.0  1805943.0  67276.0  2021-05-27 06:00:41.443295+00:00
# 14391  86872717.0  2650727.0  40005.0  2021-05-27 06:00:41.443693+00:00
#
# [123 rows x 4 columns]

# %%
df_SMTOWN_view.sort_values(["like", "dislike"], ascending=False)
# Out:
#                publish_time                channel_id channel_name  \
# 14391  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 14182  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 13966  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 13752  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 13545  2021-05-10T09:02:33Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# ...                     ...                       ...          ...
# 1055   2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 18     2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 840    2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 636    2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
# 431    2021-02-04T09:00:09Z  UCEf_Bc-KVd7onSeifS3py9g       SMTOWN
#
#        category_id        view       like  dislike  \
# 14391           10  86872717.0  2650727.0  40005.0
# 14182           10  85962829.0  2626361.0  39584.0
# ...

# %%
df.groupby("channel_name")[["like", "dislike"]].sum()
# Out:
#                                                   like  dislike
# channel_name
# #temantapimenikah                               8887.0     35.0
# (G)I-DLE (여자)아이들 (Official YouTube Channel)  2564565.0  10895.0
# 1 vs 9999                                      12729.0   3913.0
# 10 News First                                 223457.0  27381.0
# 100kpj com                                      1158.0     41.0
# ...                                                ...      ...
# 찬우살이                                           96442.0     94.0
# 채널 십오야                                       4397728.0  29123.0
# 최시원 Siwon Choi                                134408.0    256.0
# 키이스트 KEYEAST official                         130107.0    446.0
# 혀니콤보 TV                                       268274.0    333.0
#
# [1093 rows x 2 columns]

# %%
df_la_base_channel = df.loc[
    df["channel_id"].str.startswith("UC")
]
df_la_base_channel
# Out:
#                publish_time                channel_id  \
# 0      2021-02-05T09:00:34Z  UCEf_Bc-KVd7onSeifS3py9g
# 1      2021-02-04T15:54:08Z  UCYEa4_MC7OFjcWrO6SO-u8g
# 2      2021-02-06T03:00:22Z  UCu12RxQjRQyh79YBYvEDkOg
# 3      2021-02-05T20:26:08Z  UCCuzDCoI3EUOo_nhCj4noSw
# 4      2021-02-03T23:14:54Z  UC14UlmYlSNiQCBe9Eookf_A
# ...                     ...                       ...
# 14518  2021-05-18T14:59:58Z  UCzgxx_DM2Dcb9Y1spb9mUJA
# 14519  2021-05-24T09:48:50Z  UC8nOUvbfUqYRufAAFBFz72g
# 14520  2021-05-13T07:00:06Z  UCdpxBSzxXGz_J4K30YGvk_Q
# 14521  2021-05-21T10:29:06Z  UCwIzd032IQjvJ9larkdcwgg
# 14522  2021-05-22T06:00:09Z  UCfine-VxsozjW6FnssQkwLg
#
#                                                    title  \
# 0                            aespa 에스파 'Forever (약속)' MV
# 1      [FULL] Siapa di Balik Kudeta AHY? | Dua Sisi t...
# 2         CABRIOLET CHALLENGE: TANTANGAN MENGGODA (7/12)
# 3                            With Windah Basudara & Hans
# ...

# %%
df_la_base_channel[
    df_la_base_channel.category_id >= 10
].groupby(["channel_name", "view"])["like"].count()
# Out:
# channel_name                                 view
# #temantapimenikah                            151666.0     1
# (G)I-DLE (여자)아이들 (Official YouTube Channel)  3071393.0    1
#                                              3792775.0    1
#                                              4736284.0    1
#                                              5640513.0    1
#                                                          ..
# 혀니콤보 TV                                      242479.0     1
#                                              266321.0     1
#                                              294398.0     1
#                                              305019.0     1
#                                              338127.0     1
# Name: like, Length: 13733, dtype: int64

# %%
df_la_base_channel[
    (df_la_base_channel.category_id == "10")
    & (df_la_base_channel.channel_name == "SMTOWN")
    & (df_la_base_channel.view >= 7000000)
].shape[0]
# Out:
# 0
